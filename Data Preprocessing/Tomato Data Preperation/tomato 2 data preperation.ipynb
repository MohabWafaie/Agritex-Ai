# %%
import csv
import requests
import os
import hashlib
import re

def clean_filename(filename):
    # Remove invalid characters for filenames
    return re.sub(r'[\\/:*?"<>|]', '_', filename)

def download_image(url, directory):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        # Generate a unique filename based on the URL using SHA256 hash
        file_hash = hashlib.sha256(url.encode()).hexdigest()
        file_extension = url.split('.')[-1]  # Extract file extension from URL
        filename = f"{file_hash}.{file_extension}"
        filename = clean_filename(filename)  # Clean the filename

        filepath = os.path.join(directory, filename)

        # Check if file already exists, if yes, add a number to make it unique
        counter = 1
        while os.path.exists(filepath):
            filename = f"{file_hash}_{counter}.{file_extension}"
            filename = clean_filename(filename)  # Clean the filename
            filepath = os.path.join(directory, filename)
            counter += 1

        with open(filepath, 'wb') as f:
            f.write(response.content)
    else:
        print(f"Failed to download {url}")

# Set up the directory to save images
image_dir = r"D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato"
if not os.path.exists(image_dir):
    os.makedirs(image_dir)

# Path to your CSV file
file_path = r"D:\Projects\Weed Detection\mohab data\to be done\tomato\multimedia.txt"

with open(file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t')
    for row in reader:
        image_url = row['identifier']
        download_image(image_url, image_dir)

print("Download complete.")
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[1], line 47
#      45     for row in reader:
#      46         image_url = row['identifier']
# ---> 47         download_image(image_url, image_dir)
#      49 print("Download complete.")
#
# Cell In[1], line 12, in download_image(url, directory)
#      11 def download_image(url, directory):
# ---> 12     response = requests.get(url, stream=True)
#      13     if response.status_code == 200:
#      14         # Generate a unique filename based on the URL using SHA256 hash
#      15         file_hash = hashlib.sha256(url.encode()).hexdigest()
#
# File ~\anaconda3\envs\opencv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
# ...

# %%
import csv
import requests
import os
import hashlib
import re

def clean_filename(filename):
    # Remove invalid characters for filenames
    return re.sub(r'[\\/:*?"<>|]', '_', filename)

def download_image(url, directory):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        # Generate a unique filename based on the URL using SHA256 hash
        file_hash = hashlib.sha256(url.encode()).hexdigest()
        file_extension = url.split('.')[-1]  # Extract file extension from URL
        filename = f"{file_hash}.{file_extension}"
        filename = clean_filename(filename)  # Clean the filename

        filepath = os.path.join(directory, filename)

        # Check if file already exists, if yes, add a number to make it unique
        counter = 1
        while os.path.exists(filepath):
            filename = f"{file_hash}_{counter}.{file_extension}"
            filename = clean_filename(filename)  # Clean the filename
            filepath = os.path.join(directory, filename)
            counter += 1

        with open(filepath, 'wb') as f:
            f.write(response.content)
    else:
        print(f"Failed to download {url}")

# Set up the directory to save images
image_dir = r"D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato"
if not os.path.exists(image_dir):
    os.makedirs(image_dir)

# Path to your CSV file
file_path = r"D:\Projects\Weed Detection\mohab data\to be done\tomato\multimedia.txt"

with open(file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t')
    for row in reader:
        image_url = row['identifier']
        if image_url:  # Check if the URL is not empty
            print("Processing URL:", image_url)
            download_image(image_url, image_dir)
        else:
            print("Empty URL found in row, skipping...")



print("Download complete.")
# Out:
# Processing URL: https://d2seqvvyy3b8p2.cloudfront.net/bb277309beb5b75f7078aed49eb7af7b.jpg
# Processing URL: https://d2seqvvyy3b8p2.cloudfront.net/715aa1290c7b1edfc3bd1b3a3f43fc44.jpg
# Processing URL: https://d2seqvvyy3b8p2.cloudfront.net/cb31a641fdfcb480e3b2c5960fbb95c7.jpg
# Processing URL: https://d2seqvvyy3b8p2.cloudfront.net/bf5ad3ec2d580392c46c9f852456f5ee.jpg
# Processing URL: https://d2seqvvyy3b8p2.cloudfront.net/ece084571033102a4fc1aa46c9f148f3.jpg
# Processing URL: http://d2seqvvyy3b8p2.cloudfront.net/b317336f833b5bb1b735930f759cdb88.jpg
# Processing URL: http://d2seqvvyy3b8p2.cloudfront.net/d83fb267525bbe137c417fa86e732263.jpg
# Processing URL: http://d2seqvvyy3b8p2.cloudfront.net/2c67073b753d1142b7c8f81aa7871d32.jpg
# Processing URL: http://d2seqvvyy3b8p2.cloudfront.net/b0785ebfb9fd7d691cb02869fecc1060.jpg
# Processing URL: http://d2seqvvyy3b8p2.cloudfront.net/5fa62969fecfe9a7ebefaad8ca2b4ed9.jpg
# ...

# %%
import os
import imghdr  # Importing imghdr module to check image file types

# Set up the directory containing the downloaded files
image_dir = r"D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato"

# List of valid image file extensions
valid_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp', '.tiff', '.tif']

# Iterate over files in the directory
for filename in os.listdir(image_dir):
    filepath = os.path.join(image_dir, filename)
    if os.path.isfile(filepath) and not any(filepath.endswith(ext) for ext in valid_extensions):
        # If the file is not an image, delete it
        os.remove(filepath)
        print(f"Deleted {filepath}")

print("Deletion complete.")
# Out:
# Deleted D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato\01c788a933b4e89da7888cecd6d84db25a5c8cbadcb320e183e75d0ca59491b3.be_specimen_BR0000014140891_manifest
# Deleted D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato\036952fcac954cf0f6acb30ec7c0ad6022a01faf7c466053cdcb04745ffff1ae.uk_herb_iiif_E00160257_manifest
# Deleted D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato\0894db7f851bf9b63c0dc80060b60a8297c896d2058b9ec72dccfbfc7fab2170.be_specimen_BR0000008238634_manifest
# Deleted D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato\09c252ca5318ffdd272708dcbc03ad5cb063ed99dc281c464bc40cbe30bec141.org_image_o_13a2fa50625a0962f4ac7748d2385a85cc423c0e
# Deleted D:\Projects\Weed Detection\mohab data\to be done\tomato\tomato\0b971fb218359fcba97db48146372b973d0822b26719258cf4762308877d74fd.fr_media_1441363892216vmFurRNEz0lYs3cQ
# ...
